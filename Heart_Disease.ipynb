# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the data

# %%
data = pd.read_csv('Heart Disease data.csv')

# %%
print(data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# ### Checking for missing values

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### Data Visualisation

# %%
# Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Gender distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=data)
plt.title('Gender Distribution')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.show()

# %%
# Chest pain type distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='cp', data=data)
plt.title('Chest Pain Type Distribution')
plt.xlabel('Chest Pain Type (0, 1, 2, 3)')
plt.ylabel('Count')
plt.show()

# %%
# Pairplot to visualize relationships
sns.pairplot(data)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Let's visualize the relationship between age and maximum heart rate achieved
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='thalach', hue='sex', data=data)
plt.title('Age vs Maximum Heart Rate Achieved')
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate Achieved')
plt.show()

# %%
# Exploring the relationship between chest pain type and the presence of heart disease
plt.figure(figsize=(8, 5))
sns.countplot(x='cp', hue='target', data=data)
plt.title('Chest Pain Type vs Heart Disease')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.legend(title='Heart Disease (0 = No, 1 = Yes)')
plt.show()

# %%
# Analyzing Categorical Variables
# Gender vs Heart Disease
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', hue='target', data=data)
plt.title('Gender vs Heart Disease')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.legend(title='Heart Disease (0 = No, 1 = Yes)')
plt.show()

# %%
# Fasting blood sugar vs Heart Disease
plt.figure(figsize=(6, 4))
sns.countplot(x='fbs', hue='target', data=data)
plt.title('Fasting Blood Sugar vs Heart Disease')
plt.xlabel('Fasting Blood Sugar > 120 mg/dl (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.legend(title='Heart Disease (0 = No, 1 = Yes)')
plt.show()

# %%
 from sklearn.decomposition import PCA
from scipy import stats

# %%
# Distribution of Resting Blood Pressure
plt.figure(figsize=(10, 6))
sns.histplot(data['trestbps'], bins=20, kde=True)
plt.title('Resting Blood Pressure Distribution')
plt.xlabel('Resting Blood Pressure (mm Hg)')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of Cholesterol Levels
plt.figure(figsize=(10, 6))
sns.histplot(data['chol'], bins=20, kde=True)
plt.title('Cholesterol Levels Distribution')
plt.xlabel('Cholesterol (mg/dl)')
plt.ylabel('Frequency')
plt.show()

# %%
# Relationship between Chest Pain Type and Maximum Heart Rate
plt.figure(figsize=(10, 6))
sns.boxplot(x='cp', y='thalach', data=data)
plt.title('Chest Pain Type vs Maximum Heart Rate')
plt.xlabel('Chest Pain Type (0, 1, 2, 3)')
plt.ylabel('Maximum Heart Rate Achieved')
plt.show()

# %%
# Relationship between Fasting Blood Sugar and Resting Blood Pressure
plt.figure(figsize=(10, 6))
sns.boxplot(x='fbs', y='trestbps', data=data)
plt.title('Fasting Blood Sugar vs Resting Blood Pressure')
plt.xlabel('Fasting Blood Sugar > 120 mg/dl (0 = No, 1 = Yes)')
plt.ylabel('Resting Blood Pressure (mm Hg)')
plt.show()

# %% [markdown]
# ### Outlier Detection

# %%
# Identifying outliers in Resting Blood Pressure
plt.figure(figsize=(10, 6))
sns.boxplot(data['trestbps'])
plt.title('Boxplot of Resting Blood Pressure')
plt.xlabel('Resting Blood Pressure (mm Hg)')
plt.show()

# %%
# Identifying outliers in Cholesterol Levels
plt.figure(figsize=(10, 6))
sns.boxplot(data['chol'])
plt.title('Boxplot of Cholesterol Levels')
plt.xlabel('Cholesterol (mg/dl)')
plt.show()

# %%
# Creating a new feature: Age Group
data['age_group'] = pd.cut(data['age'], bins=[29, 40, 50, 60, 70, 80], labels=['30-40', '41-50', '51-60', '61-70', '71-80'])

# Creating a new feature: Cholesterol to Age Ratio
data['chol_age_ratio'] = data['chol'] / data['age']

# Distribution of Cholesterol to Age Ratio
plt.figure(figsize=(10, 6))
sns.histplot(data['chol_age_ratio'], bins=20, kde=True)
plt.title('Cholesterol to Age Ratio Distribution')
plt.xlabel('Cholesterol to Age Ratio')
plt.ylabel('Frequency')
plt.show()

# %%
# 4. Dimensionality Reduction with PCA

# Selecting numerical features for PCA
features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# Standardizing the features
data_std = (data[features] - data[features].mean()) / data[features].std()

# %%
# Applying PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data_std)

# Creating a DataFrame for the PCA results
pca_df = pd.DataFrame(data=pca_result, columns=['PCA1', 'PCA2'])

# %%
# Explained variance ratio
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.36071796 0.21510566]

# %%
# Age Group vs Heart Disease
plt.figure(figsize=(10, 6))
sns.countplot(x='age_group', hue='target', data=data)
plt.title('Age Group vs Heart Disease')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Heart Disease (0 = No, 1 = Yes)')
plt.show()

# %%
# Cholesterol to Age Ratio vs Heart Disease
plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='chol_age_ratio', data=data)
plt.title('Cholesterol to Age Ratio vs Heart Disease')
plt.xlabel('Heart Disease (0 = No, 1 = Yes)')
plt.ylabel('Cholesterol to Age Ratio')
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Handle Outliers
# For simplicity, let's assume we'll remove outliers from 'chol' and 'trestbps' using z-score method
z_scores = np.abs(stats.zscore(data[['chol', 'trestbps']]))
threshold = 3
data = data[(z_scores < threshold).all(axis=1)]

# %%
# Encode categorical variables
categorical_columns = ['cp', 'restecg', 'slope', 'thal', 'sex', 'fbs', 'exang']
label_encoder = LabelEncoder()

for col in categorical_columns:
    data[col] = label_encoder.fit_transform(data[col])

# %%
# Step 4: Feature Engineering
# Add any additional features if necessary, such as age groups or interaction terms
# For this example, let's create a 'chol_age_ratio' feature
data['chol_age_ratio'] = data['chol'] / data['age']

# %%
# Step 5: Split the data into features and target
X = data.drop(columns=['target'])  # Features
y = data['target']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 556   59    1   0       140   177    0        1      162      1      0.0
# 452   66    0   0       178   228    1        1      165      1      1.0
# 837   52    1   2       172   199    1        1      162      0      0.5
# 407   58    1   0       100   234    0        1      156      0      0.1
# 978   44    1   0       110   197    0        0      177      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 106   51    1   0       140   299    0        1      173      1      1.6
# 277   44    1   1       130   219    0        0      188      0      0.0
# 877   43    0   2       122   213    0        1      165      0      0.2
# 444   47    1   2       130   253    0        1      179      0      0.0
# 102   54    1   1       108   309    0        1      156      0      0.0
#
#      slope  ca  thal age_group  chol_age_ratio
# ...

# %%
print(X_train["age_group"])
# Out:
# 556    51-60
# 452    61-70
# 837    51-60
# 407    51-60
# 978    41-50
#        ...
# 106    51-60
# 277    41-50
# 877    41-50
# 444    41-50
# 102    51-60
# Name: age_group, Length: 703, dtype: category
# Categories (5, object): ['30-40' < '41-50' < '51-60' < '61-70' < '71-80']

# %%
df = pd.DataFrame(X_train["age_group"])

df['age_float'] = df['age_group'].apply(lambda x: (int(x.split('-')[0]) + int(x.split('-')[1])) / 2)
print(df)
# Out:
#     age_group age_float
# 556     51-60      55.5
# 452     61-70      65.5
# 837     51-60      55.5
# 407     51-60      55.5
# 978     41-50      45.5
# ..        ...       ...
# 106     51-60      55.5
# 277     41-50      45.5
# 877     41-50      45.5
# 444     41-50      45.5
# 102     51-60      55.5
#
# [703 rows x 2 columns]

# %%
X_train= pd.DataFrame(X_train)
X_train=X_train.drop("age_group",axis=1)
print(X_train)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 556   59    1   0       140   177    0        1      162      1      0.0
# 452   66    0   0       178   228    1        1      165      1      1.0
# 837   52    1   2       172   199    1        1      162      0      0.5
# 407   58    1   0       100   234    0        1      156      0      0.1
# 978   44    1   0       110   197    0        0      177      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 106   51    1   0       140   299    0        1      173      1      1.6
# 277   44    1   1       130   219    0        0      188      0      0.0
# 877   43    0   2       122   213    0        1      165      0      0.2
# 444   47    1   2       130   253    0        1      179      0      0.0
# 102   54    1   1       108   309    0        1      156      0      0.0
#
#      slope  ca  thal  chol_age_ratio
# 556      2   1     3        3.000000
# ...

# %%
X_test= pd.DataFrame(X_test)
X_test=X_test.drop("age_group",axis=1)
print(X_test)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 944   66    0   0       178   228    1        1      165      1      1.0
# 644   44    1   2       120   226    0        1      169      0      0.0
# 699   35    1   0       126   282    0        0      156      1      0.0
# 527   62    0   0       124   209    0        1      163      0      0.0
# 374   46    0   2       142   177    0        0      160      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 594   64    1   0       145   212    0        0      132      0      2.0
# 954   53    0   0       130   264    0        0      143      0      0.4
# 379   52    1   3       118   186    0        0      190      0      0.0
# 7     55    1   0       160   289    0        0      145      1      0.8
# 157   54    1   2       120   258    0        0      147      0      0.4
#
#      slope  ca  thal  chol_age_ratio
# 944      1   2     3        3.454545
# ...

# %%
# Step 7: Feature Scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# C:\Users\Rahul Shaw\anaconda3\Anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
# Step 8: Model Training and Hyperparameter Tuning
# Initialize models
logreg = LogisticRegression(random_state=42)
dtree = DecisionTreeClassifier(random_state=42)
rf = RandomForestClassifier(random_state=42)
svm = SVC(probability=True, random_state=42)

# %%
  # Hyperparameter tuning using GridSearchCV
param_grid = {
    'logreg': {'C': [0.1, 1, 10, 100], 'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
    'dtree': {'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4]},
    'rf': {'n_estimators': [50, 100, 200], 'max_depth': [None, 10, 20], 'min_samples_split': [2, 5, 10]},
    'svm': {'C': [0.1, 1, 10, 100], 'kernel': ['linear', 'rbf']}
}

# %%
# Training models with GridSearchCV
best_estimators = {}
models = {'logreg': logreg, 'dtree': dtree, 'rf': rf, 'svm': svm}

for model_name in models:
    grid_search = GridSearchCV(models[model_name], param_grid[model_name], cv=5, scoring='accuracy', n_jobs=-1)
    grid_search.fit(X_train, y_train)
    best_estimators[model_name] = grid_search.best_estimator_
    print(f"Best parameters for {model_name}: {grid_search.best_params_}")
# Out:
# Best parameters for logreg: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best parameters for dtree: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best parameters for rf: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200}
# Best parameters for svm: {'C': 100, 'kernel': 'rbf'}

# %%
# Step 9: Model Evaluation
# Predictions
y_pred_logreg = best_estimators['logreg'].predict(X_test)
y_pred_dtree = best_estimators['dtree'].predict(X_test)
y_pred_rf = best_estimators['rf'].predict(X_test)
y_pred_svm = best_estimators['svm'].predict(X_test)

# %%
# Evaluate models
print("\nLogistic Regression:")
print("Accuracy:", accuracy_score(y_test, y_pred_logreg))
print("Classification Report:\n", classification_report(y_test, y_pred_logreg))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_logreg))
# Out:
# Logistic Regression:
# Accuracy: 0.6721854304635762
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.83      0.70       141
#            1       0.78      0.53      0.63       161
#
#     accuracy                           0.67       302
#    macro avg       0.70      0.68      0.67       302
# weighted avg       0.70      0.67      0.67       302
#
# Confusion Matrix:
#  [[117  24]
#  [ 75  86]]

# %%
cm=confusion_matrix(y_test, y_pred_logreg)
# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print("\nDecision Tree:")
print("Accuracy:", accuracy_score(y_test, y_pred_dtree))
print("Classification Report:\n", classification_report(y_test, y_pred_dtree))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_dtree))
# Out:
# Decision Tree:
# Accuracy: 0.46688741721854304
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64       141
#            1       0.00      0.00      0.00       161
#
#     accuracy                           0.47       302
#    macro avg       0.23      0.50      0.32       302
# weighted avg       0.22      0.47      0.30       302
#
# Confusion Matrix:
#  [[141   0]
#  [161   0]]
# C:\Users\Rahul Shaw\anaconda3\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm=confusion_matrix(y_test, y_pred_dtree)
# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print("\nRandom Forest:")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest:
# Accuracy: 0.7152317880794702
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.66      0.79      0.72       141
#            1       0.78      0.65      0.71       161
#
#     accuracy                           0.72       302
#    macro avg       0.72      0.72      0.72       302
# weighted avg       0.72      0.72      0.71       302
#
# Confusion Matrix:
#  [[111  30]
#  [ 56 105]]

# %%
cm=confusion_matrix(y_test, y_pred_rf)
# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print("\nSupport Vector Machine:")
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
# Out:
# Support Vector Machine:
# Accuracy: 0.5331125827814569
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       141
#            1       0.53      1.00      0.70       161
#
#     accuracy                           0.53       302
#    macro avg       0.27      0.50      0.35       302
# weighted avg       0.28      0.53      0.37       302
#
# Confusion Matrix:
#  [[  0 141]
#  [  0 161]]
# C:\Users\Rahul Shaw\anaconda3\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm=confusion_matrix(y_test, y_pred_svm)
# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
